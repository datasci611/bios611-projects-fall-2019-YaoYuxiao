# %% [markdown]
# Notebook for project 3.

# %% [markdown]
# ### Import data: client

# %%
import pandas as pd
import numpy as np

client = pd.read_csv("../data/CLIENT_191102.tsv", encoding='utf-8',delimiter='\t')
client.head()
# Out:
#                                       EE Provider ID  EE UID  \
# 0  Urban Ministries of Durham - Durham County - S...  687901
# 1  Urban Ministries of Durham - Durham County - S...  687902
# 2  Urban Ministries of Durham - Durham County - S...  687903
# 3  Urban Ministries of Durham - Durham County - S...  687904
# 4  Urban Ministries of Durham - Durham County - S...  687905
#
#        Client Unique ID  Client ID  Client Age at Entry  Client Age at Exit  \
# 0  pbkf09291954p610b236     397941                 60.0                61.0
# 1  kdaf01071967k400d635     130335                 48.0                48.0
# 2  smrf06211973s620m640     188933                 42.0                42.0
# 3  abrm07251958a416b600     168290                 57.0                57.0
# 4  wbom01251964w450b620     123122                 51.0                51.0
#
#   Client Gender              Client Primary Race  \
# 0        Female                      White (HUD)
# 1        Female  Black or African American (HUD)
# 2        Female  Black or African American (HUD)
# 3          Male                      White (HUD)
# 4          Male                      White (HUD)
#
#                 Client Ethnicity Client Veteran Status
# 0  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 1  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 2  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 3          Hispanic/Latino (HUD)              No (HUD)
# 4  Non-Hispanic/Non-Latino (HUD)              No (HUD)

# %% [markdown]
# Clean data by checking values in each column.

# %%
client.groupby("EE Provider ID").size()
# Out:
# EE Provider ID
# Urban Ministries of Durham - Durham County - Singles Emergency Shelter - Private(5838)    4319
# XXXClosed2015 Urban Ministries of Durham- Durham County- Journey Entry- ESG(1970)          721
# XXXClosed2015 Urban Ministries of Durham- Durham County- Journey Forward- ESG(5694)         65
# XXXClosed2015 Urban Ministries of Durham- Durham County- Journey Outreach- ESG(4515)        51
# XXXClosed2015 Urban Ministries of Durham- Durham County- Journey Recovery- ESG(1932)        67
# XXXClosed2015 Urban Ministries of Durham- Durham County- Journey Tech- ESG(4516)            61
# XXXClosed2015 Urban Ministries of Durham- Durham County- Journey Veterans- ESG(5069)        15
# dtype: int64

# %% [markdown]
# For this project, we only keep data from "Urban Ministries of Durham - Durham County - Singles Emergency Shelter - Private(5838)" because assumedly others are closed in 2015.

# %%
client=client[client["EE Provider ID"]=='Urban Ministries of Durham - Durham County - Singles Emergency Shelter - Private(5838)']

# %%
# get the number of unique values of "Client Unique ID"
client["Client Unique ID"].nunique()
# Out:
# 2100

# %%
# get the number of unique values of "Client Unique ID"
client["Client ID"].nunique()
# Out:
# 2102

# %% [markdown]
# We have more unique "Client ID" than unique "Client Unique ID" here, so we will use "Client ID" instead of "Client Unique ID".

# %%
#drop the "Client Unique ID" and "EE Provider ID"

client = client.drop(['Client Unique ID', 'EE Provider ID'],1)
client.head()
# Out:
#    EE UID  Client ID  Client Age at Entry  Client Age at Exit Client Gender  \
# 0  687901     397941                 60.0                61.0        Female
# 1  687902     130335                 48.0                48.0        Female
# 2  687903     188933                 42.0                42.0        Female
# 3  687904     168290                 57.0                57.0          Male
# 4  687905     123122                 51.0                51.0          Male
#
#                Client Primary Race               Client Ethnicity  \
# 0                      White (HUD)  Non-Hispanic/Non-Latino (HUD)
# 1  Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 2  Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 3                      White (HUD)          Hispanic/Latino (HUD)
# 4                      White (HUD)  Non-Hispanic/Non-Latino (HUD)
#
#   Client Veteran Status
# 0              No (HUD)
# 1              No (HUD)
# 2              No (HUD)
# 3              No (HUD)
# 4              No (HUD)

# %%
client.groupby("Client Age at Entry").size()
# Out:
# Client Age at Entry
# 18.0    29
# 19.0    32
# 20.0    69
# 21.0    57
# 22.0    66
#         ..
# 76.0     5
# 77.0     6
# 78.0     1
# 80.0     1
# 81.0     1
# Length: 63, dtype: int64

# %%
client.groupby("Client Age at Exit").size()
# Out:
# Client Age at Exit
# 18.0    24
# 19.0    34
# 20.0    67
# 21.0    57
# 22.0    70
#         ..
# 75.0     3
# 76.0     4
# 77.0     6
# 78.0     2
# 81.0     2
# Length: 62, dtype: int64

# %%
client.groupby("Client Gender").size()
# Out:
# Client Gender
# Female                                  1036
# Male                                    3268
# Trans Female (MTF or Male to Female)      15
# dtype: int64

# %%
client.groupby("Client Primary Race").size()
# Out:
# Client Primary Race
# American Indian or Alaska Native (HUD)               74
# Asian (HUD)                                           3
# Black or African American (HUD)                    3133
# Client doesn't know (HUD)                             4
# Client refused (HUD)                                  2
# Data not collected (HUD)                              6
# Native Hawaiian or Other Pacific Islander (HUD)      11
# White (HUD)                                        1086
# dtype: int64

# %%
#change "Client doesn't know" "Client refused" and "Data not collected" to NaN
client['Client Primary Race']=client['Client Primary Race'].replace("Client doesn't know (HUD)", np.NaN).replace("Client refused (HUD)", np.NaN).replace("Data not collected (HUD)", np.NaN)
client.groupby("Client Primary Race").size()
# Out:
# Client Primary Race
# American Indian or Alaska Native (HUD)               74
# Asian (HUD)                                           3
# Black or African American (HUD)                    3133
# Native Hawaiian or Other Pacific Islander (HUD)      11
# White (HUD)                                        1086
# dtype: int64

# %%
client.groupby("Client Ethnicity").size()
# Out:
# Client Ethnicity
# Client doesn't know (HUD)           5
# Client refused (HUD)                4
# Data not collected (HUD)            3
# Hispanic/Latino (HUD)             163
# Non-Hispanic/Non-Latino (HUD)    4144
# dtype: int64

# %%
client['Client Ethnicity']=client['Client Ethnicity'].replace("Client doesn't know (HUD)", np.NaN).replace("Client refused (HUD)", np.NaN).replace("Data not collected (HUD)", np.NaN)
client.groupby("Client Ethnicity").size()
# Out:
# Client Ethnicity
# Hispanic/Latino (HUD)             163
# Non-Hispanic/Non-Latino (HUD)    4144
# dtype: int64

# %%
client.groupby("Client Veteran Status").size()
# Out:
# Client Veteran Status
# Data not collected (HUD)       2
# No (HUD)                    3848
# Yes (HUD)                    461
# dtype: int64

# %%
client['Client Veteran Status']=client['Client Veteran Status'].replace("Data not collected (HUD)", np.NaN)
client.groupby("Client Veteran Status").size()
# Out:
# Client Veteran Status
# No (HUD)     3848
# Yes (HUD)     461
# dtype: int64

# %% [markdown]
# 3. Import data: entry_exit

# %%
entry_exit = pd.read_csv("../data/ENTRY_EXIT_191102.tsv", encoding='utf-8',delimiter='\t')
entry_exit.head()
# Out:
#                                       EE Provider ID  EE UID  \
# 0  Urban Ministries of Durham - Durham County - S...  687901
# 1  Urban Ministries of Durham - Durham County - S...  687902
# 2  Urban Ministries of Durham - Durham County - S...  687903
# 3  Urban Ministries of Durham - Durham County - S...  687904
# 4  Urban Ministries of Durham - Durham County - S...  687905
#
#        Client Unique ID  Client ID  Entry Exit Group Id  \
# 0  pbkf09291954p610b236     397941                  NaN
# 1  kdaf01071967k400d635     130335                  NaN
# 2  smrf06211973s620m640     188933                  NaN
# 3  abrm07251958a416b600     168290                  NaN
# 4  wbom01251964w450b620     123122                  NaN
#
#    Entry Exit Household Id  Unnamed: 6 Entry Date Housing Move-in Date(5584)  \
# 0                      NaN         NaN  8/15/2015                  4/20/2015
# 1                      NaN         NaN  8/15/2015                        NaN
# 2                      NaN         NaN  8/15/2015                        NaN
# 3                      NaN         NaN  8/15/2015                        NaN
# 4                      NaN         NaN  8/15/2015                        NaN
#
#    Exit Date                                        Destination  \
# 0  7/11/2016  Rental by client, with other ongoing housing s...
# 1  8/31/2015                           Data not collected (HUD)
# 2  9/19/2015  Staying or living with friends, temporary tenu...
# 3   3/7/2016  Hospital or other residential non-psychiatric ...
# 4  8/24/2015  Staying or living with friends, temporary tenu...
#
#        Reason for Leaving Entry Exit Type Entry Exit Date Added  \
# 0       Completed program             HUD             8/19/2015
# 1  Needs could not be met             HUD             8/19/2015
# 2                   Other             HUD             8/19/2015
# 3                   Other             HUD             8/19/2015
# 4                   Other             HUD             8/19/2015
#
#   Entry Exit Date Updated
# 0               7/20/2016
# 1                9/3/2015
# 2               9/22/2015
# 3                3/8/2016
# 4               8/25/2015

# %% [markdown]
# 4. Clean data: basicly the same thing as client data

# %%
entry_exit.groupby("EE Provider ID").size()
entry_exit=entry_exit[entry_exit["EE Provider ID"]=='Urban Ministries of Durham - Durham County - Singles Emergency Shelter - Private(5838)']

# %%
entry_exit = entry_exit.drop(['Client Unique ID', 'EE Provider ID','Entry Exit Group Id','Entry Exit Household Id','Unnamed: 6','Housing Move-in Date(5584)'],1)
entry_exit.head()
# Out:
#    EE UID  Client ID Entry Date  Exit Date  \
# 0  687901     397941  8/15/2015  7/11/2016
# 1  687902     130335  8/15/2015  8/31/2015
# 2  687903     188933  8/15/2015  9/19/2015
# 3  687904     168290  8/15/2015   3/7/2016
# 4  687905     123122  8/15/2015  8/24/2015
#
#                                          Destination      Reason for Leaving  \
# 0  Rental by client, with other ongoing housing s...       Completed program
# 1                           Data not collected (HUD)  Needs could not be met
# 2  Staying or living with friends, temporary tenu...                   Other
# 3  Hospital or other residential non-psychiatric ...                   Other
# 4  Staying or living with friends, temporary tenu...                   Other
#
#   Entry Exit Type Entry Exit Date Added Entry Exit Date Updated
# 0             HUD             8/19/2015               7/20/2016
# 1             HUD             8/19/2015                9/3/2015
# 2             HUD             8/19/2015               9/22/2015
# 3             HUD             8/19/2015                3/8/2016
# 4             HUD             8/19/2015               8/25/2015

# %%
entry_exit['Destination']=entry_exit['Destination'].replace("Client doesn't know (HUD)", np.NaN).replace("Client refused (HUD)", np.NaN).replace("Data not collected (HUD)", np.NaN)
entry_exit.groupby("Destination").size()
# Out:
# Destination
# Deceased (HUD)                                                                                           3
# Emergency shelter, incl. hotel/motel paid for w/ ES voucher, or RHY-funded Host Home shelter (HUD)      29
# Hospital or other residential non-psychiatric medical facility (HUD)                                   137
# Hotel or motel paid for without emergency shelter voucher (HUD)                                         17
# Jail, prison or juvenile detention facility (HUD)                                                       44
# Long-term care facility or nursing home (HUD)                                                            5
# No exit interview completed (HUD)                                                                      958
# Other (HUD)                                                                                              3
# Owned by client, no ongoing housing subsidy (HUD)                                                        5
# Owned by client, with ongoing housing subsidy (HUD)                                                      2
# Permanent housing (other than RRH) for formerly homeless persons (HUD)                                  14
# Place not meant for habitation (HUD)                                                                   147
# Psychiatric hospital or other psychiatric facility (HUD)                                                34
# Rental by client in a public housing unit (HUD)                                                          1
# Rental by client, no ongoing housing subsidy (HUD)                                                     248
# Rental by client, with RRH or equivalent subsidy (HUD)                                                  45
# Rental by client, with VASH housing subsidy (HUD)                                                       12
# Rental by client, with other ongoing housing subsidy (HUD)                                             149
# Residential project or halfway house with no homeless criteria (HUD)                                     5
# Safe Haven (HUD)                                                                                         3
# Staying or living with family, permanent tenure (HUD)                                                  141
# Staying or living with family, temporary tenure (HUD)                                                  401
# Staying or living with friends, permanent tenure (HUD)                                                  72
# Staying or living with friends, temporary tenure (HUD)                                                1406
# Substance abuse treatment facility or detox center (HUD)                                                12
# Transitional housing for homeless persons (including homeless youth) (HUD)                              29
# dtype: int64

# %%
entry_exit.groupby("Reason for Leaving").size()
# Out:
# Reason for Leaving
# Completed program                                       354
# Criminal activity / violence                             80
# Death                                                     4
# Disagreement with rules/persons                          21
# Does not or no longer qualifies for program              17
# Left for housing opp. before completing program         393
# Needs could not be met                                   98
# Non-compliance with program                             288
# Other                                                  1809
# Reached maximum time allowed                             12
# Unknown/Disappeared                                    1133
# z-Left before completing program (not a HUD answer)       3
# dtype: int64

# %%
entry_exit.groupby("Entry Exit Type").size()
# Out:
# Entry Exit Type
# HUD    4319
# dtype: int64

# %%
entry_exit = entry_exit.drop(['Entry Exit Type','Entry Exit Date Added','Entry Exit Date Updated'],1)
entry_exit.head()
# Out:
#    EE UID  Client ID Entry Date  Exit Date  \
# 0  687901     397941  8/15/2015  7/11/2016
# 1  687902     130335  8/15/2015  8/31/2015
# 2  687903     188933  8/15/2015  9/19/2015
# 3  687904     168290  8/15/2015   3/7/2016
# 4  687905     123122  8/15/2015  8/24/2015
#
#                                          Destination      Reason for Leaving
# 0  Rental by client, with other ongoing housing s...       Completed program
# 1                                                NaN  Needs could not be met
# 2  Staying or living with friends, temporary tenu...                   Other
# 3  Hospital or other residential non-psychiatric ...                   Other
# 4  Staying or living with friends, temporary tenu...                   Other

# %%
entry_exit[['Entry Date', 'Exit Date']] = entry_exit[['Entry Date', 'Exit Date']].apply(pd.to_datetime)
entry_exit['stay_days']=entry_exit['Exit Date'] - entry_exit['Entry Date']
entry_exit.head()
# Out:
#    EE UID  Client ID Entry Date  Exit Date  \
# 0  687901     397941 2015-08-15 2016-07-11
# 1  687902     130335 2015-08-15 2015-08-31
# 2  687903     188933 2015-08-15 2015-09-19
# 3  687904     168290 2015-08-15 2016-03-07
# 4  687905     123122 2015-08-15 2015-08-24
#
#                                          Destination      Reason for Leaving  \
# 0  Rental by client, with other ongoing housing s...       Completed program
# 1                                                NaN  Needs could not be met
# 2  Staying or living with friends, temporary tenu...                   Other
# 3  Hospital or other residential non-psychiatric ...                   Other
# 4  Staying or living with friends, temporary tenu...                   Other
#
#   stay_days
# 0  331 days
# 1   16 days
# 2   35 days
# 3  205 days
# 4    9 days

# %% [markdown]
# 5. Import data: ee_udes

# %%
ee_udes = pd.read_csv("../data/EE_UDES_191102.tsv", delimiter='\t', encoding='utf-8')
ee_udes.head()
# Out:
#                                       EE Provider ID  \
# 0  Urban Ministries of Durham - Durham County - S...
# 1  Urban Ministries of Durham - Durham County - S...
# 2  Urban Ministries of Durham - Durham County - S...
# 3  Urban Ministries of Durham - Durham County - S...
# 4  Urban Ministries of Durham - Durham County - S...
#
#   Entry Exit Provider Program Type Code  EE UID      Client Unique ID  \
# 0               Emergency Shelter (HUD)  687901  pbkf09291954p610b236
# 1               Emergency Shelter (HUD)  687902  kdaf01071967k400d635
# 2               Emergency Shelter (HUD)  687903  smrf06211973s620m640
# 3               Emergency Shelter (HUD)  687904  abrm07251958a416b600
# 4               Emergency Shelter (HUD)  687905  wbom01251964w450b620
#
#    Client ID              Client Location(4378)  \
# 0     397941  NC-502 Durham City and County CoC
# 1     130335  NC-502 Durham City and County CoC
# 2     188933  NC-502 Durham City and County CoC
# 3     168290  NC-502 Durham City and County CoC
# 4     123122  NC-502 Durham City and County CoC
#
#   Zip Code (of Last Permanent Address, if known)(1932)  \
# 0                                              27701
# 1                                              29033
# 2                                              27703
# 3                                              27603
# 4                                              27510
#
#   Relationship to Head of Household(4374)  \
# 0                Self (head of household)
# 1                Self (head of household)
# 2                Self (head of household)
# 3                Self (head of household)
# 4                Self (head of household)
#
#                           Prior Living Situation(43)  \
# 0  Staying or living in a friend's room, apartmen...
# 1  Staying or living in a family member's room, a...
# 2  Staying or living in a friend's room, apartmen...
# 3  Staying or living in a friend's room, apartmen...
# 4  Staying or living in a friend's room, apartmen...
#
#       Length of Stay in Previous Place(1934)  ...  \
# 0                   One year or longer (HUD)  ...
# 1   One month or more, but less than 90 days  ...
# 2   One month or more, but less than 90 days  ...
# 3                   One year or longer (HUD)  ...
# 4  One week or more, but less than one month  ...
#
#   Did you stay less than 90 days?(5163)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   On the night before did you stay on the streets, ES or SH?(5165)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(5167)  \
# 0                                    Two times (HUD)
# 1                           Four or more times (HUD)
# 2                           Four or more times (HUD)
# 3                           Four or more times (HUD)
# 4                           Four or more times (HUD)
#
#   Total number of months homeless on the street, in ES or SH in the past three years(5168)  \
# 0                                                  2
# 1                          More than 12 months (HUD)
# 2                          More than 12 months (HUD)
# 3                           Data not collected (HUD)
# 4                          More than 12 months (HUD)
#
#           Housing Status(2703)  \
# 0  Category 1 - Homeless (HUD)
# 1  Category 1 - Homeless (HUD)
# 2  Category 1 - Homeless (HUD)
# 3  Category 1 - Homeless (HUD)
# 4  Category 1 - Homeless (HUD)
#
#   Does the client have a disabling condition?(1935)  \
# 0                                         Yes (HUD)
# 1                                         Yes (HUD)
# 2                                         Yes (HUD)
# 3                                         Yes (HUD)
# 4                                         Yes (HUD)
#
#   Covered by Health Insurance(4376) Domestic violence victim/survivor(341)  \
# 0                         Yes (HUD)                               No (HUD)
# 1                         Yes (HUD)                              Yes (HUD)
# 2                          No (HUD)                               No (HUD)
# 3                          No (HUD)                               No (HUD)
# 4                          No (HUD)                               No (HUD)
#
#   If yes for Domestic violence victim/survivor, when experience occurred(1917)  \
# 0                                                NaN
# 1                         More than a year ago (HUD)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Date of Birth(893)
# 0          9/29/1954
# 1           1/7/1967
# 2          6/21/1973
# 3          7/25/1958
# 4          1/25/1964
#
# [5 rows x 21 columns]

# %%
ee_udes=ee_udes[ee_udes["EE Provider ID"]=='Urban Ministries of Durham - Durham County - Singles Emergency Shelter - Private(5838)']

# %%
ee_udes = ee_udes.drop(['Client Unique ID', 'EE Provider ID'],1)
ee_udes.head()
# Out:
#   Entry Exit Provider Program Type Code  EE UID  Client ID  \
# 0               Emergency Shelter (HUD)  687901     397941
# 1               Emergency Shelter (HUD)  687902     130335
# 2               Emergency Shelter (HUD)  687903     188933
# 3               Emergency Shelter (HUD)  687904     168290
# 4               Emergency Shelter (HUD)  687905     123122
#
#                Client Location(4378)  \
# 0  NC-502 Durham City and County CoC
# 1  NC-502 Durham City and County CoC
# 2  NC-502 Durham City and County CoC
# 3  NC-502 Durham City and County CoC
# 4  NC-502 Durham City and County CoC
#
#   Zip Code (of Last Permanent Address, if known)(1932)  \
# 0                                              27701
# 1                                              29033
# 2                                              27703
# 3                                              27603
# 4                                              27510
#
#   Relationship to Head of Household(4374)  \
# 0                Self (head of household)
# 1                Self (head of household)
# 2                Self (head of household)
# 3                Self (head of household)
# 4                Self (head of household)
#
#                           Prior Living Situation(43)  \
# 0  Staying or living in a friend's room, apartmen...
# 1  Staying or living in a family member's room, a...
# 2  Staying or living in a friend's room, apartmen...
# 3  Staying or living in a friend's room, apartmen...
# 4  Staying or living in a friend's room, apartmen...
#
#       Length of Stay in Previous Place(1934)  \
# 0                   One year or longer (HUD)
# 1   One month or more, but less than 90 days
# 2   One month or more, but less than 90 days
# 3                   One year or longer (HUD)
# 4  One week or more, but less than one month
#
#   Did you stay less than 7 nights?(5164)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Did you stay less than 90 days?(5163)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   On the night before did you stay on the streets, ES or SH?(5165)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(5167)  \
# 0                                    Two times (HUD)
# 1                           Four or more times (HUD)
# 2                           Four or more times (HUD)
# 3                           Four or more times (HUD)
# 4                           Four or more times (HUD)
#
#   Total number of months homeless on the street, in ES or SH in the past three years(5168)  \
# 0                                                  2
# 1                          More than 12 months (HUD)
# 2                          More than 12 months (HUD)
# 3                           Data not collected (HUD)
# 4                          More than 12 months (HUD)
#
#           Housing Status(2703)  \
# 0  Category 1 - Homeless (HUD)
# 1  Category 1 - Homeless (HUD)
# 2  Category 1 - Homeless (HUD)
# 3  Category 1 - Homeless (HUD)
# 4  Category 1 - Homeless (HUD)
#
#   Does the client have a disabling condition?(1935)  \
# 0                                         Yes (HUD)
# 1                                         Yes (HUD)
# 2                                         Yes (HUD)
# 3                                         Yes (HUD)
# 4                                         Yes (HUD)
#
#   Covered by Health Insurance(4376) Domestic violence victim/survivor(341)  \
# 0                         Yes (HUD)                               No (HUD)
# 1                         Yes (HUD)                              Yes (HUD)
# 2                          No (HUD)                               No (HUD)
# 3                          No (HUD)                               No (HUD)
# 4                          No (HUD)                               No (HUD)
#
#   If yes for Domestic violence victim/survivor, when experience occurred(1917)  \
# 0                                                NaN
# 1                         More than a year ago (HUD)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Date of Birth(893)
# 0          9/29/1954
# 1           1/7/1967
# 2          6/21/1973
# 3          7/25/1958
# 4          1/25/1964

# %%
#How many rows in dataframe?
ee_udes.shape[0]
# Out:
# 4319

# %%
ee_udes.groupby("Did you stay less than 7 nights?(5164)").size()
# Out:
# Did you stay less than 7 nights?(5164)
# No     15
# Yes     4
# dtype: int64

# %%
ee_udes.groupby("Did you stay less than 90 days?(5163)").size()
# Out:
# Did you stay less than 90 days?(5163)
# No      1
# Yes    10
# dtype: int64

# %%
ee_udes.groupby("On the night before did you stay on the streets, ES or SH?(5165)").size()
# Out:
# On the night before did you stay on the streets, ES or SH?(5165)
# No      4
# Yes    10
# dtype: int64

# %%
ee_udes.groupby("If yes for Domestic violence victim/survivor, when experience occurred(1917)").size()
# Out:
# If yes for Domestic violence victim/survivor, when experience occurred(1917)
# Client doesn't know (HUD)                4
# Client refused (HUD)                     7
# Data not collected (HUD)                22
# From six to twelve months ago (HUD)     32
# More than a year ago (HUD)             195
# Three to six months ago (HUD)           38
# Within the past three months (HUD)     107
# dtype: int64

# %% [markdown]
# Drop four columns above since there are too many missing values.

# %%
ee_udes = ee_udes.drop(['Did you stay less than 7 nights?(5164)', 'Did you stay less than 90 days?(5163)','On the night before did you stay on the streets, ES or SH?(5165)','If yes for Domestic violence victim/survivor, when experience occurred(1917)'],1)
ee_udes.head()
# Out:
#   Entry Exit Provider Program Type Code  EE UID  Client ID  \
# 0               Emergency Shelter (HUD)  687901     397941
# 1               Emergency Shelter (HUD)  687902     130335
# 2               Emergency Shelter (HUD)  687903     188933
# 3               Emergency Shelter (HUD)  687904     168290
# 4               Emergency Shelter (HUD)  687905     123122
#
#                Client Location(4378)  \
# 0  NC-502 Durham City and County CoC
# 1  NC-502 Durham City and County CoC
# 2  NC-502 Durham City and County CoC
# 3  NC-502 Durham City and County CoC
# 4  NC-502 Durham City and County CoC
#
#   Zip Code (of Last Permanent Address, if known)(1932)  \
# 0                                              27701
# 1                                              29033
# 2                                              27703
# 3                                              27603
# 4                                              27510
#
#   Relationship to Head of Household(4374)  \
# 0                Self (head of household)
# 1                Self (head of household)
# 2                Self (head of household)
# 3                Self (head of household)
# 4                Self (head of household)
#
#                           Prior Living Situation(43)  \
# 0  Staying or living in a friend's room, apartmen...
# 1  Staying or living in a family member's room, a...
# 2  Staying or living in a friend's room, apartmen...
# 3  Staying or living in a friend's room, apartmen...
# 4  Staying or living in a friend's room, apartmen...
#
#       Length of Stay in Previous Place(1934)  \
# 0                   One year or longer (HUD)
# 1   One month or more, but less than 90 days
# 2   One month or more, but less than 90 days
# 3                   One year or longer (HUD)
# 4  One week or more, but less than one month
#
#   Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(5167)  \
# 0                                    Two times (HUD)
# 1                           Four or more times (HUD)
# 2                           Four or more times (HUD)
# 3                           Four or more times (HUD)
# 4                           Four or more times (HUD)
#
#   Total number of months homeless on the street, in ES or SH in the past three years(5168)  \
# 0                                                  2
# 1                          More than 12 months (HUD)
# 2                          More than 12 months (HUD)
# 3                           Data not collected (HUD)
# 4                          More than 12 months (HUD)
#
#           Housing Status(2703)  \
# 0  Category 1 - Homeless (HUD)
# 1  Category 1 - Homeless (HUD)
# 2  Category 1 - Homeless (HUD)
# 3  Category 1 - Homeless (HUD)
# 4  Category 1 - Homeless (HUD)
#
#   Does the client have a disabling condition?(1935)  \
# 0                                         Yes (HUD)
# 1                                         Yes (HUD)
# 2                                         Yes (HUD)
# 3                                         Yes (HUD)
# 4                                         Yes (HUD)
#
#   Covered by Health Insurance(4376) Domestic violence victim/survivor(341)  \
# 0                         Yes (HUD)                               No (HUD)
# 1                         Yes (HUD)                              Yes (HUD)
# 2                          No (HUD)                               No (HUD)
# 3                          No (HUD)                               No (HUD)
# 4                          No (HUD)                               No (HUD)
#
#   Date of Birth(893)
# 0          9/29/1954
# 1           1/7/1967
# 2          6/21/1973
# 3          7/25/1958
# 4          1/25/1964

# %%
ee_reviews = pd.read_csv("../data/EE_REVIEWS_191102.tsv", delimiter='\t', encoding='utf-8')
ee_reviews.head()
# Out:
#                                       EE Provider ID  EE UID  \
# 0  Urban Ministries of Durham - Durham County - S...  687973
# 1  Urban Ministries of Durham - Durham County - S...  687973
# 2  Urban Ministries of Durham - Durham County - S...  688366
# 3  Urban Ministries of Durham - Durham County - S...  688366
# 4  Urban Ministries of Durham - Durham County - S...  688366
#
#        Client Unique ID  Client ID  Entry Exit Review Uid  \
# 0  pswf10261963p362s620     399028                  26744
# 1  pswf10261963p362s620     399028                  32030
# 2  wbsf12081963w530b200     373187                  26749
# 3  wbsf12081963w530b200     373187                  30241
# 4  wbsf12081963w530b200     373187                  32029
#
#   Entry Exit Review Point in Time Type Entry Exit Review Date  \
# 0                       Interim Review               1/7/2016
# 1                       Interim Review              4/20/2016
# 2                       Interim Review               1/7/2016
# 3                       Interim Review              4/18/2016
# 4                       Interim Review              4/25/2016
#
#   Entry Exit Review Date Updated  \
# 0                       1/7/2016
# 1                      6/16/2016
# 2                       1/7/2016
# 3                      4/18/2016
# 4                      6/16/2016
#
#                  Entry Exit Review Provider Updating
# 0  Urban Ministries of Durham - Durham County - S...
# 1  XXXClosed2016 Urban Ministries of Durham - Dur...
# 2  Urban Ministries of Durham - Durham County - S...
# 3  Urban Ministries of Durham - Durham County - S...
# 4  XXXClosed2016 Urban Ministries of Durham - Dur...

# %%
# Out:
#        EE UID  Client ID  Client Age at Entry  Client Age at Exit  \
# 0      687901     397941                 60.0                61.0
# 1      687902     130335                 48.0                48.0
# 2      687903     188933                 42.0                42.0
# 3      687904     168290                 57.0                57.0
# 4      687905     123122                 51.0                51.0
# ...       ...        ...                  ...                 ...
# 4314  1074322     166411                 31.0                31.0
# 4315  1074391     198376                 39.0                39.0
# 4316  1074405    1004266                 59.0                59.0
# 4317  1074495     407506                 22.0                22.0
# 4318  1074506     429149                 52.0                52.0
#
#      Client Gender              Client Primary Race  \
# 0           Female                      White (HUD)
# 1           Female  Black or African American (HUD)
# 2           Female  Black or African American (HUD)
# 3             Male                      White (HUD)
# 4             Male                      White (HUD)
# ...            ...                              ...
# 4314          Male                      White (HUD)
# 4315          Male                      White (HUD)
# 4316          Male  Black or African American (HUD)
# 4317          Male  Black or African American (HUD)
# 4318        Female  Black or African American (HUD)
#
#                    Client Ethnicity Client Veteran Status
# 0     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 1     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 2     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 3             Hispanic/Latino (HUD)              No (HUD)
# 4     Non-Hispanic/Non-Latino (HUD)              No (HUD)
# ...                             ...                   ...
# 4314  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 4315  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 4316  Non-Hispanic/Non-Latino (HUD)                   NaN
# 4317  Non-Hispanic/Non-Latino (HUD)              No (HUD)
# 4318  Non-Hispanic/Non-Latino (HUD)              No (HUD)
#
# [4319 rows x 8 columns]

# %%
client["EE UID"].nunique()
# Out:
# 4319

# %%
entry_exit["EE UID"].nunique()
# Out:
# 4319

# %%
ee_udes["EE UID"].nunique()
# Out:
# 4319

# %% [markdown]
# ### Merge data
# The data frames of "client" "entry_exit" and "ee_udes" have the same number of "EE UID" values. Join them on this key.

# %%
merged_data=pd.merge(pd.merge(client, entry_exit, how='left', on='EE UID'),ee_udes,how='left', on='EE UID')
merged_data = merged_data.drop(['Client ID_y', 'Client ID'],1)
df.rename(columns={"Client ID_x": "Client ID"})
merged_data
# Out:
#        EE UID  Client ID_x  Client Age at Entry  Client Age at Exit  \
# 0      687901       397941                 60.0                61.0
# 1      687902       130335                 48.0                48.0
# 2      687903       188933                 42.0                42.0
# 3      687904       168290                 57.0                57.0
# 4      687905       123122                 51.0                51.0
# ...       ...          ...                  ...                 ...
# 4314  1074322       166411                 31.0                31.0
# 4315  1074391       198376                 39.0                39.0
# 4316  1074405      1004266                 59.0                59.0
# 4317  1074495       407506                 22.0                22.0
# 4318  1074506       429149                 52.0                52.0
#
#      Client Gender              Client Primary Race  \
# 0           Female                      White (HUD)
# 1           Female  Black or African American (HUD)
# 2           Female  Black or African American (HUD)
# 3             Male                      White (HUD)
# 4             Male                      White (HUD)
# ...            ...                              ...
# 4314          Male                      White (HUD)
# 4315          Male                      White (HUD)
# 4316          Male  Black or African American (HUD)
# 4317          Male  Black or African American (HUD)
# 4318        Female  Black or African American (HUD)
#
#                    Client Ethnicity Client Veteran Status  Client ID_y  \
# 0     Non-Hispanic/Non-Latino (HUD)              No (HUD)       397941
# 1     Non-Hispanic/Non-Latino (HUD)              No (HUD)       130335
# 2     Non-Hispanic/Non-Latino (HUD)              No (HUD)       188933
# 3             Hispanic/Latino (HUD)              No (HUD)       168290
# 4     Non-Hispanic/Non-Latino (HUD)              No (HUD)       123122
# ...                             ...                   ...          ...
# 4314  Non-Hispanic/Non-Latino (HUD)              No (HUD)       166411
# 4315  Non-Hispanic/Non-Latino (HUD)              No (HUD)       198376
# 4316  Non-Hispanic/Non-Latino (HUD)                   NaN      1004266
# 4317  Non-Hispanic/Non-Latino (HUD)              No (HUD)       407506
# 4318  Non-Hispanic/Non-Latino (HUD)              No (HUD)       429149
#
#      Entry Date  ... Relationship to Head of Household(4374)  \
# 0    2015-08-15  ...                Self (head of household)
# 1    2015-08-15  ...                Self (head of household)
# 2    2015-08-15  ...                Self (head of household)
# 3    2015-08-15  ...                Self (head of household)
# 4    2015-08-15  ...                Self (head of household)
# ...         ...  ...                                     ...
# 4314 2019-10-23  ...                Self (head of household)
# 4315 2019-10-24  ...                Self (head of household)
# 4316 2019-10-24  ...                Self (head of household)
# 4317 2019-10-25  ...                Self (head of household)
# 4318 2019-10-25  ...                Self (head of household)
#
#                              Prior Living Situation(43)  \
# 0     Staying or living in a friend's room, apartmen...
# 1     Staying or living in a family member's room, a...
# 2     Staying or living in a friend's room, apartmen...
# 3     Staying or living in a friend's room, apartmen...
# 4     Staying or living in a friend's room, apartmen...
# ...                                                 ...
# 4314    Rental by client in a public housing unit (HUD)
# 4315               Place not meant for habitation (HUD)
# 4316               Place not meant for habitation (HUD)
# 4317  Psychiatric hospital or other psychiatric faci...
# 4318  Staying or living in a friend's room, apartmen...
#
#          Length of Stay in Previous Place(1934)  \
# 0                      One year or longer (HUD)
# 1      One month or more, but less than 90 days
# 2      One month or more, but less than 90 days
# 3                      One year or longer (HUD)
# 4     One week or more, but less than one month
# ...                                         ...
# 4314                   One year or longer (HUD)
# 4315                   One year or longer (HUD)
# 4316                          One night or less
# 4317                          Two to six nights
# 4318                          One night or less
#
#      Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(5167)  \
# 0                                       Two times (HUD)
# 1                              Four or more times (HUD)
# 2                              Four or more times (HUD)
# 3                              Four or more times (HUD)
# 4                              Four or more times (HUD)
# ...                                                 ...
# 4314                                     One time (HUD)
# 4315                                     One time (HUD)
# 4316                                    Two times (HUD)
# 4317                           Four or more times (HUD)
# 4318                                  Three times (HUD)
#
#      Total number of months homeless on the street, in ES or SH in the past three years(5168)  \
# 0                                                     2
# 1                             More than 12 months (HUD)
# 2                             More than 12 months (HUD)
# 3                              Data not collected (HUD)
# 4                             More than 12 months (HUD)
# ...                                                 ...
# 4314                                                  3
# 4315     One month (this time is the first month) (HUD)
# 4316     One month (this time is the first month) (HUD)
# 4317                          More than 12 months (HUD)
# 4318                          More than 12 months (HUD)
#
#                                    Housing Status(2703)  \
# 0                           Category 1 - Homeless (HUD)
# 1                           Category 1 - Homeless (HUD)
# 2                           Category 1 - Homeless (HUD)
# 3                           Category 1 - Homeless (HUD)
# 4                           Category 1 - Homeless (HUD)
# ...                                                 ...
# 4314                                                NaN
# 4315                        Category 1 - Homeless (HUD)
# 4316                        Category 1 - Homeless (HUD)
# 4317  Category 2 - At imminent risk of losing housin...
# 4318  Category 2 - At imminent risk of losing housin...
#
#      Does the client have a disabling condition?(1935)  \
# 0                                            Yes (HUD)
# 1                                            Yes (HUD)
# 2                                            Yes (HUD)
# 3                                            Yes (HUD)
# 4                                            Yes (HUD)
# ...                                                ...
# 4314                                         Yes (HUD)
# 4315                                          No (HUD)
# 4316                                          No (HUD)
# 4317                                         Yes (HUD)
# 4318                                          No (HUD)
#
#      Covered by Health Insurance(4376) Domestic violence victim/survivor(341)  \
# 0                            Yes (HUD)                               No (HUD)
# 1                            Yes (HUD)                              Yes (HUD)
# 2                             No (HUD)                               No (HUD)
# 3                             No (HUD)                               No (HUD)
# 4                             No (HUD)                               No (HUD)
# ...                                ...                                    ...
# 4314                         Yes (HUD)                               No (HUD)
# 4315                          No (HUD)                               No (HUD)
# 4316                          No (HUD)                               No (HUD)
# 4317                         Yes (HUD)                               No (HUD)
# 4318                         Yes (HUD)                              Yes (HUD)
#
#      Date of Birth(893)
# 0             9/29/1954
# 1              1/7/1967
# 2             6/21/1973
# 3             7/25/1958
# 4             1/25/1964
# ...                 ...
# 4314           3/1/1988
# 4315          10/7/1980
# 4316          8/27/1960
# 4317          4/27/1997
# 4318         11/25/1966
#
# [4319 rows x 28 columns]

# %% [markdown]
# Keep only clients' first entry and merge data frames on "Client ID".

# %%
client_first = client.drop_duplicates(subset='Client ID', keep='first')
client_first = client_first.drop(['EE UID'],1)
entry_exit_first=entry_exit.drop_duplicates(subset='Client ID', keep='first')
entry_exit_first = entry_exit_first.drop(['EE UID'],1)
ee_udes_first=ee_udes.drop_duplicates(subset='Client ID', keep='first')
ee_udes_first = ee_udes_first.drop(['EE UID'],1)
merged_data_client=pd.merge(pd.merge(client_first, entry_exit_first, how='left', on='Client ID'),ee_udes_first,how='left', on='Client ID')
merged_data_client

# %%
# Out:
#       Client ID  Client Age at Entry  Client Age at Exit Client Gender  \
# 0        397941                 60.0                61.0        Female
# 1        130335                 48.0                48.0        Female
# 2        188933                 42.0                42.0        Female
# 3        168290                 57.0                57.0          Male
# 4        123122                 51.0                51.0          Male
# ...         ...                  ...                 ...           ...
# 2097    1004126                 18.0                18.0        Female
# 2098    1003651                 53.0                53.0          Male
# 2099     166411                 31.0                31.0          Male
# 2100     198376                 39.0                39.0          Male
# 2101    1004266                 59.0                59.0          Male
#
#                   Client Primary Race               Client Ethnicity  \
# 0                         White (HUD)  Non-Hispanic/Non-Latino (HUD)
# 1     Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 2     Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 3                         White (HUD)          Hispanic/Latino (HUD)
# 4                         White (HUD)  Non-Hispanic/Non-Latino (HUD)
# ...                               ...                            ...
# 2097  Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
# 2098                      White (HUD)  Non-Hispanic/Non-Latino (HUD)
# 2099                      White (HUD)  Non-Hispanic/Non-Latino (HUD)
# 2100                      White (HUD)  Non-Hispanic/Non-Latino (HUD)
# 2101  Black or African American (HUD)  Non-Hispanic/Non-Latino (HUD)
#
#      Client Veteran Status Entry Date  Exit Date  \
# 0                 No (HUD) 2015-08-15 2016-07-11
# 1                 No (HUD) 2015-08-15 2015-08-31
# 2                 No (HUD) 2015-08-15 2015-09-19
# 3                 No (HUD) 2015-08-15 2016-03-07
# 4                 No (HUD) 2015-08-15 2015-08-24
# ...                    ...        ...        ...
# 2097                   NaN 2019-10-20        NaT
# 2098              No (HUD) 2019-10-22        NaT
# 2099              No (HUD) 2019-10-23        NaT
# 2100              No (HUD) 2019-10-24 2019-10-25
# 2101                   NaN 2019-10-24 2019-10-25
#
#                                             Destination  ...  \
# 0     Rental by client, with other ongoing housing s...  ...
# 1                                                   NaN  ...
# 2     Staying or living with friends, temporary tenu...  ...
# 3     Hospital or other residential non-psychiatric ...  ...
# 4     Staying or living with friends, temporary tenu...  ...
# ...                                                 ...  ...
# 2097                                                NaN  ...
# 2098                                                NaN  ...
# 2099                                                NaN  ...
# 2100                  No exit interview completed (HUD)  ...
# 2101                  No exit interview completed (HUD)  ...
#
#      Relationship to Head of Household(4374)  \
# 0                   Self (head of household)
# 1                   Self (head of household)
# 2                   Self (head of household)
# 3                   Self (head of household)
# 4                   Self (head of household)
# ...                                      ...
# 2097                Self (head of household)
# 2098                Self (head of household)
# 2099                Self (head of household)
# 2100                Self (head of household)
# 2101                Self (head of household)
#
#                              Prior Living Situation(43)  \
# 0     Staying or living in a friend's room, apartmen...
# 1     Staying or living in a family member's room, a...
# 2     Staying or living in a friend's room, apartmen...
# 3     Staying or living in a friend's room, apartmen...
# 4     Staying or living in a friend's room, apartmen...
# ...                                                 ...
# 2097  Hospital or other residential non-psychiatric ...
# 2098               Place not meant for habitation (HUD)
# 2099    Rental by client in a public housing unit (HUD)
# 2100               Place not meant for habitation (HUD)
# 2101               Place not meant for habitation (HUD)
#
#          Length of Stay in Previous Place(1934)  \
# 0                      One year or longer (HUD)
# 1      One month or more, but less than 90 days
# 2      One month or more, but less than 90 days
# 3                      One year or longer (HUD)
# 4     One week or more, but less than one month
# ...                                         ...
# 2097  One week or more, but less than one month
# 2098                   One year or longer (HUD)
# 2099                   One year or longer (HUD)
# 2100                   One year or longer (HUD)
# 2101                          One night or less
#
#      Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(5167)  \
# 0                                       Two times (HUD)
# 1                              Four or more times (HUD)
# 2                              Four or more times (HUD)
# 3                              Four or more times (HUD)
# 4                              Four or more times (HUD)
# ...                                                 ...
# 2097                                                NaN
# 2098                                                NaN
# 2099                                     One time (HUD)
# 2100                                     One time (HUD)
# 2101                                    Two times (HUD)
#
#      Total number of months homeless on the street, in ES or SH in the past three years(5168)  \
# 0                                                     2
# 1                             More than 12 months (HUD)
# 2                             More than 12 months (HUD)
# 3                              Data not collected (HUD)
# 4                             More than 12 months (HUD)
# ...                                                 ...
# 2097                                                NaN
# 2098                                                NaN
# 2099                                                  3
# 2100     One month (this time is the first month) (HUD)
# 2101     One month (this time is the first month) (HUD)
#
#                                    Housing Status(2703)  \
# 0                           Category 1 - Homeless (HUD)
# 1                           Category 1 - Homeless (HUD)
# 2                           Category 1 - Homeless (HUD)
# 3                           Category 1 - Homeless (HUD)
# 4                           Category 1 - Homeless (HUD)
# ...                                                 ...
# 2097  Category 2 - At imminent risk of losing housin...
# 2098                        Category 1 - Homeless (HUD)
# 2099                                                NaN
# 2100                        Category 1 - Homeless (HUD)
# 2101                        Category 1 - Homeless (HUD)
#
#      Does the client have a disabling condition?(1935)  \
# 0                                            Yes (HUD)
# 1                                            Yes (HUD)
# 2                                            Yes (HUD)
# 3                                            Yes (HUD)
# 4                                            Yes (HUD)
# ...                                                ...
# 2097                                         Yes (HUD)
# 2098                                         Yes (HUD)
# 2099                                         Yes (HUD)
# 2100                                          No (HUD)
# 2101                                          No (HUD)
#
#      Covered by Health Insurance(4376) Domestic violence victim/survivor(341)  \
# 0                            Yes (HUD)                               No (HUD)
# 1                            Yes (HUD)                              Yes (HUD)
# 2                             No (HUD)                               No (HUD)
# 3                             No (HUD)                               No (HUD)
# 4                             No (HUD)                               No (HUD)
# ...                                ...                                    ...
# 2097                         Yes (HUD)                              Yes (HUD)
# 2098                               NaN                                    NaN
# 2099                         Yes (HUD)                               No (HUD)
# 2100                          No (HUD)                               No (HUD)
# 2101                          No (HUD)                               No (HUD)
#
#      Date of Birth(893)
# 0             9/29/1954
# 1              1/7/1967
# 2             6/21/1973
# 3             7/25/1958
# 4             1/25/1964
# ...                 ...
# 2097           2/6/2001
# 2098           9/4/1966
# 2099           3/1/1988
# 2100          10/7/1980
# 2101          8/27/1960
#
# [2102 rows x 25 columns]

# %%
merged_data.to_csv("../data/merged_data.tsv", sep='\t')

# %%
merged_data_client.to_csv("../data/merged_data_client.tsv", sep='\t')

# %%
for column in merged_data.columns: 
    print(column)
# Out:
# EE UID
# Client ID_x
# Client Age at Entry
# Client Age at Exit
# Client Gender
# Client Primary Race
# Client Ethnicity
# Client Veteran Status
# Client ID_y
# Entry Date
# Exit Date
# Destination
# Reason for Leaving
# stay_days
# Entry Exit Provider Program Type Code
# Client ID
# Client Location(4378)
# Zip Code (of Last Permanent Address, if known)(1932)
# Relationship to Head of Household(4374)
# Prior Living Situation(43)
# Length of Stay in Previous Place(1934)
# Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(5167)
# Total number of months homeless on the street, in ES or SH in the past three years(5168)
# Housing Status(2703)
# Does the client have a disabling condition?(1935)
# Covered by Health Insurance(4376)
# Domestic violence victim/survivor(341)
# Date of Birth(893)

# %%
all_sort = merged_data.sort_values(by=['Entry Date'], ascending=True)
all_sort
# Out:
#        EE UID  Client ID_x  Client Age at Entry  Client Age at Exit  \
# 143    690620       194903                 32.0                32.0
# 137    689741       231530                 40.0                40.0
# 0      687901       397941                 60.0                61.0
# 85     688737        10107                 59.0                59.0
# 84     688735       330427                 68.0                68.0
# ...       ...          ...                  ...                 ...
# 4314  1074322       166411                 31.0                31.0
# 4315  1074391       198376                 39.0                39.0
# 4316  1074405      1004266                 59.0                59.0
# 4317  1074495       407506                 22.0                22.0
# 4318  1074506       429149                 52.0                52.0
#
#      Client Gender              Client Primary Race  \
# 143           Male  Black or African American (HUD)
# 137           Male  Black or African American (HUD)
# 0           Female                      White (HUD)
# 85            Male  Black or African American (HUD)
# 84            Male  Black or African American (HUD)
# ...            ...                              ...
# 4314          Male                      White (HUD)
# 4315          Male                      White (HUD)
# 4316          Male  Black or African American (HUD)
# 4317          Male  Black or African American (HUD)
# 4318        Female  Black or African American (HUD)
#
#                    Client Ethnicity Client Veteran Status  Client ID_y  \
# 143   Non-Hispanic/Non-Latino (HUD)              No (HUD)       194903
# 137   Non-Hispanic/Non-Latino (HUD)              No (HUD)       231530
# 0     Non-Hispanic/Non-Latino (HUD)              No (HUD)       397941
# 85    Non-Hispanic/Non-Latino (HUD)              No (HUD)        10107
# 84    Non-Hispanic/Non-Latino (HUD)              No (HUD)       330427
# ...                             ...                   ...          ...
# 4314  Non-Hispanic/Non-Latino (HUD)              No (HUD)       166411
# 4315  Non-Hispanic/Non-Latino (HUD)              No (HUD)       198376
# 4316  Non-Hispanic/Non-Latino (HUD)                   NaN      1004266
# 4317  Non-Hispanic/Non-Latino (HUD)              No (HUD)       407506
# 4318  Non-Hispanic/Non-Latino (HUD)              No (HUD)       429149
#
#      Entry Date  ... Relationship to Head of Household(4374)  \
# 143  2015-08-13  ...                Self (head of household)
# 137  2015-08-13  ...                Self (head of household)
# 0    2015-08-15  ...                Self (head of household)
# 85   2015-08-15  ...                Self (head of household)
# 84   2015-08-15  ...                Self (head of household)
# ...         ...  ...                                     ...
# 4314 2019-10-23  ...                Self (head of household)
# 4315 2019-10-24  ...                Self (head of household)
# 4316 2019-10-24  ...                Self (head of household)
# 4317 2019-10-25  ...                Self (head of household)
# 4318 2019-10-25  ...                Self (head of household)
#
#                              Prior Living Situation(43)  \
# 143   Jail, prison or juvenile detention facility (HUD)
# 137   Emergency shelter, incl. hotel/motel paid for ...
# 0     Staying or living in a friend's room, apartmen...
# 85    Emergency shelter, incl. hotel/motel paid for ...
# 84    Hotel or motel paid for without emergency shel...
# ...                                                 ...
# 4314    Rental by client in a public housing unit (HUD)
# 4315               Place not meant for habitation (HUD)
# 4316               Place not meant for habitation (HUD)
# 4317  Psychiatric hospital or other psychiatric faci...
# 4318  Staying or living in a friend's room, apartmen...
#
#          Length of Stay in Previous Place(1934)  \
# 143    One month or more, but less than 90 days
# 137     90 days or more, but less than one year
# 0                      One year or longer (HUD)
# 85     One month or more, but less than 90 days
# 84    One week or more, but less than one month
# ...                                         ...
# 4314                   One year or longer (HUD)
# 4315                   One year or longer (HUD)
# 4316                          One night or less
# 4317                          Two to six nights
# 4318                          One night or less
#
#      Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(5167)  \
# 143                            Four or more times (HUD)
# 137                                      One time (HUD)
# 0                                       Two times (HUD)
# 85                                    Three times (HUD)
# 84                                       One time (HUD)
# ...                                                 ...
# 4314                                     One time (HUD)
# 4315                                     One time (HUD)
# 4316                                    Two times (HUD)
# 4317                           Four or more times (HUD)
# 4318                                  Three times (HUD)
#
#      Total number of months homeless on the street, in ES or SH in the past three years(5168)  \
# 143                           More than 12 months (HUD)
# 137                            Data not collected (HUD)
# 0                                                     2
# 85                             Data not collected (HUD)
# 84                             Data not collected (HUD)
# ...                                                 ...
# 4314                                                  3
# 4315     One month (this time is the first month) (HUD)
# 4316     One month (this time is the first month) (HUD)
# 4317                          More than 12 months (HUD)
# 4318                          More than 12 months (HUD)
#
#                                    Housing Status(2703)  \
# 143                         Category 1 - Homeless (HUD)
# 137                         Category 1 - Homeless (HUD)
# 0                           Category 1 - Homeless (HUD)
# 85                          Category 1 - Homeless (HUD)
# 84                          Category 1 - Homeless (HUD)
# ...                                                 ...
# 4314                                                NaN
# 4315                        Category 1 - Homeless (HUD)
# 4316                        Category 1 - Homeless (HUD)
# 4317  Category 2 - At imminent risk of losing housin...
# 4318  Category 2 - At imminent risk of losing housin...
#
#      Does the client have a disabling condition?(1935)  \
# 143                                           No (HUD)
# 137                                           No (HUD)
# 0                                            Yes (HUD)
# 85                                           Yes (HUD)
# 84                                           Yes (HUD)
# ...                                                ...
# 4314                                         Yes (HUD)
# 4315                                          No (HUD)
# 4316                                          No (HUD)
# 4317                                         Yes (HUD)
# 4318                                          No (HUD)
#
#      Covered by Health Insurance(4376) Domestic violence victim/survivor(341)  \
# 143                           No (HUD)                               No (HUD)
# 137                           No (HUD)                               No (HUD)
# 0                            Yes (HUD)                               No (HUD)
# 85                            No (HUD)                               No (HUD)
# 84                            No (HUD)                               No (HUD)
# ...                                ...                                    ...
# 4314                         Yes (HUD)                               No (HUD)
# 4315                          No (HUD)                               No (HUD)
# 4316                          No (HUD)                               No (HUD)
# 4317                         Yes (HUD)                               No (HUD)
# 4318                         Yes (HUD)                              Yes (HUD)
#
#      Date of Birth(893)
# 143          11/13/1982
# 137          10/21/1974
# 0             9/29/1954
# 85            9/11/1955
# 84            5/25/1947
# ...                 ...
# 4314           3/1/1988
# 4315          10/7/1980
# 4316          8/27/1960
# 4317          4/27/1997
# 4318         11/25/1966
#
# [4319 rows x 28 columns]

# %%
health_ins_entry = pd.read_csv("../data/HEALTH_INS_ENTRY_191102.tsv", delimiter='\t', encoding='utf-8')
health_ins_entry.head()
# Out:
#                                       EE Provider ID  EE UID  \
# 0  Urban Ministries of Durham - Durham County - S...  687901
# 1  Urban Ministries of Durham - Durham County - S...  687901
# 2  Urban Ministries of Durham - Durham County - S...  687901
# 3  Urban Ministries of Durham - Durham County - S...  687901
# 4  Urban Ministries of Durham - Durham County - S...  687901
#
#        Client Unique ID  Client ID Covered (Entry)  \
# 0  pbkf09291954p610b236     397941              No
# 1  pbkf09291954p610b236     397941              No
# 2  pbkf09291954p610b236     397941              No
# 3  pbkf09291954p610b236     397941              No
# 4  pbkf09291954p610b236     397941              No
#
#              Health Insurance Type (Entry)  \
# 0     Employer - Provided Health Insurance
# 1  Health Insurance obtained through COBRA
# 2           Indian Health Services Program
# 3                                 MEDICAID
# 4                                 MEDICARE
#
#   Health Insurance Start Date (Entry) Health Insurance End Date (Entry)  \
# 0                           4/20/2015                               NaN
# 1                           4/20/2015                               NaN
# 2                            6/9/2015                               NaN
# 3                           4/20/2014                               NaN
# 4                           4/20/2015                               NaN
#
#                             Provider (4307-provider)  \
# 0   Urban Ministries of Durham - Durham County(1562)
# 1   Urban Ministries of Durham - Durham County(1562)
# 2  Urban Ministries of Durham - Durham County - S...
# 3   Urban Ministries of Durham - Durham County(1562)
# 4   Urban Ministries of Durham - Durham County(1562)
#
#    Recordset ID (4307-recordset_id) Date Added (4307-date_added)
# 0                           2261535                    7/16/2015
# 1                           2261536                    7/16/2015
# 2                           4677504                   12/22/2016
# 3                           1959563                    4/21/2015
# 4                           2261533                    7/16/2015

# %%
health_ins_exit = pd.read_csv("../data/HEALTH_INS_EXIT_191102.tsv", delimiter='\t', encoding='utf-8')
health_ins_exit.head()
# Out:
#                                       EE Provider ID  EE UID  \
# 0  Urban Ministries of Durham - Durham County - S...  687901
# 1  Urban Ministries of Durham - Durham County - S...  687901
# 2  Urban Ministries of Durham - Durham County - S...  687901
# 3  Urban Ministries of Durham - Durham County - S...  687901
# 4  Urban Ministries of Durham - Durham County - S...  687901
#
#        Client Unique ID  Client ID Covered (Exit)  \
# 0  pbkf09291954p610b236     397941             No
# 1  pbkf09291954p610b236     397941             No
# 2  pbkf09291954p610b236     397941             No
# 3  pbkf09291954p610b236     397941             No
# 4  pbkf09291954p610b236     397941             No
#
#               Health Insurance Type (Exit) Health Insurance Start Date (Exit)  \
# 0     Employer - Provided Health Insurance                          4/20/2015
# 1  Health Insurance obtained through COBRA                          4/20/2015
# 2           Indian Health Services Program                           6/9/2015
# 3                                 MEDICAID                          4/20/2014
# 4                                 MEDICARE                          4/20/2015
#
#   Health Insurance End Date (Exit)  Recordset ID (4307-recordset_id)  \
# 0                              NaN                           2261535
# 1                              NaN                           2261536
# 2                              NaN                           4677504
# 3                              NaN                           1959563
# 4                              NaN                           2261533
#
#                             Provider (4307-provider)  \
# 0   Urban Ministries of Durham - Durham County(1562)
# 1   Urban Ministries of Durham - Durham County(1562)
# 2  Urban Ministries of Durham - Durham County - S...
# 3   Urban Ministries of Durham - Durham County(1562)
# 4   Urban Ministries of Durham - Durham County(1562)
#
#   Date Added (4307-date_added)
# 0                    7/16/2015
# 1                    7/16/2015
# 2                   12/22/2016
# 3                    4/21/2015
# 4                    7/16/2015

# %%
income_entry = pd.read_csv("../data/INCOME_ENTRY_191102.tsv", delimiter='\t', encoding='utf-8')
income_entry.head()
# Out:
#                                       EE Provider ID  EE UID  \
# 0  Urban Ministries of Durham - Durham County - S...  687901
# 1  Urban Ministries of Durham - Durham County - S...  687901
# 2  Urban Ministries of Durham - Durham County - S...  687901
# 3  Urban Ministries of Durham - Durham County - S...  687901
# 4  Urban Ministries of Durham - Durham County - S...  687901
#
#        Client Unique ID  Client ID Receiving Income (Entry)  \
# 0  pbkf09291954p610b236     397941                       No
# 1  pbkf09291954p610b236     397941                       No
# 2  pbkf09291954p610b236     397941                       No
# 3  pbkf09291954p610b236     397941                       No
# 4  pbkf09291954p610b236     397941                       No
#
#                     Income Source (Entry)  Monthly Amount (Entry)  \
# 0  Alimony or Other Spousal Support (HUD)                     NaN
# 1                     Child Support (HUD)                     NaN
# 2                     Earned Income (HUD)                     NaN
# 3                General Assistance (HUD)                     NaN
# 4                             Other (HUD)                     NaN
#
#   Income Start Date (Entry) Income End Date (Entry)  \
# 0                 4/20/2015                     NaN
# 1                 4/20/2015                     NaN
# 2                 4/20/2015                     NaN
# 3                 4/20/2015                     NaN
# 4                 4/20/2015                     NaN
#
#    Recordset ID (140-recordset_id)  \
# 0                          3263585
# 1                          3263586
# 2                          3263590
# 3                          3263587
# 4                          3263599
#
#                              Provider (140-provider)  \
# 0  Urban Ministries of Durham - Durham County - S...
# 1  Urban Ministries of Durham - Durham County - S...
# 2  Urban Ministries of Durham - Durham County - S...
# 3  Urban Ministries of Durham - Durham County - S...
# 4  Urban Ministries of Durham - Durham County - S...
#
#   Date Added (140-date_added)
# 0                  12/31/2015
# 1                  12/31/2015
# 2                  12/31/2015
# 3                  12/31/2015
# 4                  12/31/2015
